# %% [markdown]
# ## 范数
# 范数是用来衡量向量大小的一个方法，$L^p$范数的定义如下：
#
# $$
# \|x\|_p = (\sum_{i}|x_i|^p)^{1/p}
# $$
#
# 其中，$p\geq1$，且一个范数必须满足下面的性质（只要满足下面的性质就可以称之为范数）:
#
# $$
# f(x)=0\Rightarrow x=0\\
# f(x+y) \leq f(x) + f(y)\\
# \forall \alpha \in \mathbb{R}， f(\alpha x) = |\alpha|f(x)
# $$

# %% [markdown]
# - 范数可以看作向量到原点的距离
# - 最常使用的是L2范数
